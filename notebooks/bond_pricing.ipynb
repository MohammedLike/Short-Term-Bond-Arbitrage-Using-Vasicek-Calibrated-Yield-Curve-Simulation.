# %%
import sys
import os

# Add the project root (one level up from the notebook)
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.bond_pricing import zero_coupon_bond_price_vasicek, generate_yield_curve
import numpy as np

# %%
# Example Vasicek parameters (replace with calibrated ones)
r_t = 0.03    # current short rate (3%)
a = 0.1       # speed of mean reversion
b = 0.05      # long-term mean
sigma = 0.01  # volatility

# Example maturities
maturities = np.linspace(0.1, 5, 50)

# Generate yield curve
yields = generate_yield_curve(r_t, a, b, sigma, maturities)

# Plot yield curve
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(maturities, yields, label="Vasicek Yield Curve")
plt.xlabel("Maturity (Years)")
plt.ylabel("Yield")
plt.title("Zero-Coupon Yield Curve (Vasicek Model)")
plt.grid(True)
plt.legend()
plt.show()
